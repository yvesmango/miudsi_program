# %% [markdown]
# # Module One: Introduction to the Data Visualization Course
#
# Please go through the following notebooks in that order.
#
#
# ## Topics covered
# - Introduction
# - Types of visualization: infovis vs. sciviz
# - Impact of visualization: classical examples
# - Anscombe's quartet, cholera map, Minard's map of 1812, etc.
# - Why visualize data
#
#
# ## Notebook Shortcuts
#
# ### Labs
# - [Intro to Data Visualization](labs/L1_DataViz_Intro.ipynb)
# - [Lecture Slides](labs/L1_DataViz_Intro.pdf) (right-click and save)
#
#
# ### Practices
# - [Cholera Map Data Set Practice](practices/L1_CholeraMap_Practice.ipynb)
# - [Anscombe Data Set Practice](practices/L1_Anscombe_Practice.ipynb)
# - [Anscombe Data Set Python Practice](practices/L1_Anscombe_Practice_Python.ipynb)
#
#
# ### Exercises
# - [R Exercise](exercises/Data_Visualization_Intro_R.ipynb)
# - [Python Exercise](exercises/Data_Visualization_Intro_Python.ipynb)
#
#
#
# ## Readings
# - **Check lab notebooks for links to reading materials and details.**
#
# - [ggplot2 Documentation](https://cran.r-project.org/web/packages/ggplot2/ggplot2.pdf)
# - [cheatsheet for ggplot2 library](https://github.com/rstudio/cheatsheets/blob/master/data-visualization-2.1.pdf)
#
# - #### Notable Figures in History of Visualization
#
#   - **William Playfair**: Founder of graphical methods for statistics: **invented bar charts, pie charts**, etc. [Wikipedia Article](https://en.wikipedia.org/wiki/William_Playfair)
#
#   - **Florence Nightingale**: Founder of modern nursing and statistician: invented coxcomb (or rose) charts. [Wikipedia Article](https://en.wikipedia.org/wiki/Florence_Nightingale)
#
#  - [How We Got To Now - S01E01 Clean](https://vimeo.com/182860286): This episode contains the **story of John Snow's cholera map and its impact leading to the development of epidemiology**. Look at lab notebook for details.
#
#
#  - [Minard's World](https://www.youtube.com/watch?v=sQdpQkDGCAU) contains a nice video about his visualization of cotton trade.
#
#  - [DataViz History: Charles Minard’s Flow Map of Napoleon’s Russian Campaign of 1812](https://datavizblog.com/2013/05/26/dataviz-history-charles-minards-flow-map-of-napoleons-russian-campaign-of-1812-part-5/)
#
#  - [Re-Visions of Minard](http://www.datavis.ca/gallery/re-minard.php)
#
#  - [John Snow’s Cholera data in more formats](http://blog.rtwilson.com/john-snows-cholera-data-in-more-formats/): modern renderings of John Snow's map.
#
#  - [John Snow's Map](https://www.arcgis.com/apps/PublicInformation/index.html?appid=d7deb67f810d46dfacb80ff80ac224e9): interactive map (click on legend and layers; by the end of the visualization courses, you will be able to create visualizations like this).
#
#
#
#
# ## Video topics
# - **Concept Video**: Introduction to Data Visualization on Canvas.
#
#
#
# ## Suggested Schedule
#
# ### Monday-Wednesday
# - **Concept Video**: Introduction to Data Visualization
# - **Lab Notebook**: L1_DataViz_Intro.ipynb
# - **Lecture Slides**: L1_DataViz_Intro.pdf
# - **Practice Notebook**: L1_Anscombe_Practice.ipynb
#
#
# ### Wednesday
# - Discussion
#
# ### Thursday
# - Discussion Responses
#
# ### Wednesday-Saturday
# - **Exercise**: Data_Visualization_Intro_Python.ipynb
# - **Exercise**: Data_Visualization_Intro_R.ipynb
