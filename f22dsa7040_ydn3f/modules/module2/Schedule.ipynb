# %% [markdown]
# # Module Two: Color and Human Visual Perception
#
# ## Topics covered
#    - Perceptual distortions in color: simul. contrast, color blindness, etc.
#    - Using colors for quantitative vs. qualitative data
#      - choosing color maps: colorbrewer
#      - bad example: avoid rainbow color map
#    -  Preattentive Processing
#     - basic visual properties
#     - perceptual/spatial grouping
#     - Gestalt principles
#    - Practice and exercise: samples of color maps from colorbrewer, changing colormaps in ggplot2
#
# ## Notebook Shortcuts
#
# ### Labs
# - [Color and Preattentive Processing](labs/L2_Color_Preattentive.ipynb)
# - [Lecture Slides](labs/L2_DataViz_Color.pdf)
# - [Lecture Slides](labs/L2_DataViz_Preattentive.pdf)
#
#
# ### Practices
# - [L2 Practice](practices/L2_Practice.ipynb)
# - [L2 Python_Practice](practices/L2_Python_Practice.ipynb)
# - [L2 Seaborn_Practice](practices/L2_Seaborn_Practice.ipynb)
#
#
# ### Exercises
# - [R Exercise](exercises/L2_Exercise.ipynb)
#
#
#
# ## Readings
# These are good reads to dig deeper into the choice of color for visualization and understanding color spaces:
#
# * [HCL-Based Color Palettes in R](https://cran.r-project.org/web/packages/colorspace/vignettes/hcl-colors.pdf)
#
# * [Escaping RGBland: Selecting Colors for Statistical Graphics](http://statmath.wu.ac.at/~zeileis/papers/Zeileis+Hornik+Murrell-2009.pdf)
#
# * [Frequently Asked Questions about Color](http://www.poynton.com/PDFs/ColorFAQ.pdf)
#
#
#
#
# ## Video topics
# - **Concept Video**: Color
# - **Concept Video**: Preattentive Processing
#
#
#
#
# ## Suggested Schedule
#
# ### Saturday-Wednesday
# - **Concept Video**: Color
# - **Concept Video**: Preattentive Processing
# - **Lab Notebook**: L2_Color_Preattentive.ipynb
# - **Lecture Slides**: L2_Color.pdf
# - **Lecture Slides**: L2_Preattentive.pdf
# - **Practice Notebooks**: L2_Practice.ipynb L2_Python_Practice.ipynb L2_Seaborn_Practice.ipynb
# - **Practice Notebooks**: L2_Python_Practice.ipynb
#
#
# ### Wednesday
# - Discussion
#
# ### Thursday
# - Discussion Responses
#
# ### Saturday-Saturday
# - **Exercise**: L2_Exercise.ipynb
